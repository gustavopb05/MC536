# %% [markdown]
# # World Health Organization Data
#
# ## Global Health Observatory
#
# * [Data query API](https://apps.who.int/gho/data/node.resources.api)
# * [GHO OData API ](https://www.who.int/data/gho/info/gho-odata-api)
#
# Exemplos de API: [https://www.who.int/data/gho/info/athena-api-examples](https://www.who.int/data/gho/info/athena-api-examples).
#
# Para se determinar o tipo de informação para acesso veja a [lista de dimensões e códigos](https://apps.who.int/gho/athena/api/GHO). Utilize o código disponível no campo `<Code label="">`. Por exemplo, no campo `<Code Label="WHOSIS_000001">` é possível encontrar o código `WHOSIS_000001` que indica `Life expectancy at birth (years)`.
#
# Depois de estabelecida a informação, podem ser configurados parâmetros, com o sufixo `?` depois da URL. Os parâmetros são separados por `&`.
#
# Os códigos dos países são encontrados em: [https://apps.who.int/gho/athena/api/COUNTRY](https://apps.who.int/gho/athena/api/COUNTRY).

# %% [markdown]
# ## Importando dados em JSON no Python
#
# ![JSON](json.png)

# %%
import io
import requests
import json
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA&format=json"
js = requests.get(url).content
print(js.decode("utf-8"))

# %% [markdown]
# ### Mostrando o Copyright

# %%
import io
import requests
import json
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA&format=json"
data = requests.get(url)
js = data.json()
print(js["copyright"])
# Out:
# (c) World Health Organization

# %% [markdown]
# ## Importando dados em CSV no Python
#
# ![CSV](csv.png)

# %%
import pandas as pd
import io
import requests
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA&format=csv"
data = requests.get(url).content
csv = pd.read_csv(io.StringIO(data.decode("utf-8")))
print(csv)

# %% [markdown]
# # Mostrando o Copyright

# %% [markdown]
# # Importando dados em XML no Python
#
# ![XML](xml.png)

# %%
import io
import requests
import xml.etree.ElementTree as et
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA"
data = requests.get(url).content
x = et.parse(io.StringIO(data.decode("utf-8")))
print(x)
# Out:
# <xml.etree.ElementTree.ElementTree object at 0x7ff5cb490b50>

# %% [markdown]
# # Mostrando o Copyright

# %% [markdown]
# # Tarefa 1
#
# Das fontes de dados disponíveis, tente encontrar fontes com formatos diferentes e importá-las via Python. Busque pelo menos dois formatos.

# %%
import pandas as pd
import io
import requests
url = "https://dashboard.healthit.gov/api/open-api.php?source=Meaningful-Use-Acceleration-Scorecard.csv"
data = requests.get(url).content
csv = pd.read_csv(io.StringIO(data.decode("utf-8")))
print(csv)
# Out:
# Empty DataFrame
# Columns: [[{"region":"National", region_code:"US", period:"2016", pct_md_pa_np_mu_aiu:"0.63", pct_md_pa_np_mu:"0.53", pct_md_mu_aiu:"0.7", pct_md_mu:"0.62", pct_np_mu_aiu:"0.48", pct_np_mu:"0.22", pct_pa_mu_aiu:"0.041", pct_pa_mu:"0.021", pct_hospitals_mu_aiu:"0.99", pct_hospitals_mu:"0.98", pct_cah_small_rural_mu_aiu:"0.99", pct_cah_small_rural_mu:"0.98"}, {"region":"Alabama", region_code:"AL", period:"2016".1, pct_md_pa_np_mu_aiu:"0.6", pct_md_pa_np_mu:"0.5", pct_md_mu_aiu:"0.66", pct_md_mu:"0.58", pct_np_mu_aiu:"0.36", pct_np_mu:"0.15", pct_pa_mu_aiu:"0.037", pct_pa_mu:"0.006", pct_hospitals_mu_aiu:"1", pct_hospitals_mu:"1", pct_cah_small_rural_mu_aiu:"1", pct_cah_small_rural_mu:"1"}, {"region":"Alaska", region_code:"AK", period:"2016".2, pct_md_pa_np_mu_aiu:"0.48", pct_md_pa_np_mu:"0.38", pct_md_mu_aiu:"0.56", pct_md_mu:"0.46", pct_np_mu_aiu:"0.5", pct_np_mu:"0.32", pct_pa_mu_aiu:"0.052", pct_pa_mu:"0.015", pct_hospitals_mu_aiu:"1".1, pct_hospitals_mu:"1".1, pct_cah_small_rural_mu_aiu:"1".1, pct_cah_small_rural_mu:"1"}.1, {"region":"Arizona", region_code:"AZ", period:"2016".3, pct_md_pa_np_mu_aiu:"0.55", pct_md_pa_np_mu:"0.44", pct_md_mu_aiu:"0.66".1, pct_md_mu:"0.54", pct_np_mu_aiu:"0.34", pct_np_mu:"0.12", pct_pa_mu_aiu:"0.01", pct_pa_mu:"0.001", pct_hospitals_mu_aiu:"1".2, pct_hospitals_mu:"0.99", pct_cah_small_rural_mu_aiu:"1".2, pct_cah_small_rural_mu:"1"}.2, {"region":"Arkansas", region_code:"AR", period:"2016".4, pct_md_pa_np_mu_aiu:"0.7", pct_md_pa_np_mu:"0.58", pct_md_mu_aiu:"0.73", pct_md_mu:"0.66", pct_np_mu_aiu:"0.63", pct_np_mu:"0.28", pct_pa_mu_aiu:"0.046", pct_pa_mu:"0.02", pct_hospitals_mu_aiu:"0.99".1, pct_hospitals_mu:"0.99".1, pct_cah_small_rural_mu_aiu:"1".3, pct_cah_small_rural_mu:"1"}.3, {"region":"California", region_code:"CA", period:"2016".5, pct_md_pa_np_mu_aiu:"0.54", pct_md_pa_np_mu:"0.43", pct_md_mu_aiu:"0.57", pct_md_mu:"0.47", pct_np_mu_aiu:"0.57", pct_np_mu:"0.24", pct_pa_mu_aiu:"0.166", pct_pa_mu:"0.083", pct_hospitals_mu_aiu:"0.99".2, pct_hospitals_mu:"0.98".1, pct_cah_small_rural_mu_aiu:"0.95", pct_cah_small_rural_mu:"0.95"}, {"region":"Colorado", region_code:"CO", period:"2016".6, pct_md_pa_np_mu_aiu:"0.64", pct_md_pa_np_mu:"0.52", pct_md_mu_aiu:"0.74", pct_md_mu:"0.64", pct_np_mu_aiu:"0.57".1, pct_np_mu:"0.23", pct_pa_mu_aiu:"0.057", ...]
# Index: []
#
# [0 rows x 3121 columns]

# %%
import io
import requests
import json
url = "https://www.healthdata.gov/data.json"
data = requests.get(url)
js = data.json()
print(js["@type"])
# Out:
# dcat:Catalog

# %% [markdown]
# # Tarefa 2
#
# ## Engenharia reversa
#
# Monte um diagramas que representem modelos dos dados que você terá acesso e como pretende associá-los. Coloque abaixo uma imagem do diagrama.
